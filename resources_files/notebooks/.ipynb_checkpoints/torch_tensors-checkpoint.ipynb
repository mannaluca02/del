# %%
import torch

# %% [markdown]
# #### Initialization

# %%
# from lists
x = torch.Tensor([5, 3])
x, x.shape, x.dtype, x.device
# Out:
# (tensor([5., 3.]), torch.Size([2]), torch.float32, device(type='cpu'))

# %%
# with zeros or ones
x = torch.zeros([3, 2])
x, x.shape
# Out:
# (tensor([[0., 0.],
#          [0., 0.],
#          [0., 0.]]),
#  torch.Size([3, 2]))

# %%
y = torch.ones([2, 3])
y, y.shape
# Out:
# (tensor([[1., 1., 1.],
#          [1., 1., 1.]]),
#  torch.Size([2, 3]))

# %%
# random uniform 
x = torch.rand([2, 5])
x, x.shape
# Out:
# (tensor([[0.7150, 0.6901, 0.0885, 0.9966, 0.3383],
#          [0.1825, 0.3467, 0.0149, 0.0241, 0.6109]]),
#  torch.Size([2, 5]))

# %%
# random normal
y = torch.randn([2, 5])
y, y.shape
# Out:
# (tensor([[ 0.9396, -1.5596,  1.0496,  0.5502,  0.3348],
#          [-0.1075,  1.6506,  1.5472, -0.2135, -1.3682]]),
#  torch.Size([2, 5]))

# %% [markdown]
# #### Operations

# %%
x = torch.Tensor([5, 3, 1])
y = torch.Tensor([2, 4, 8])

# %%
# element-wise operations
print('Addition: ', x + y)
print('Subtraction: ', x - y)
print('Multiplication: ', x * y)
print('Division: ', x / y)
print((x-y).abs())
# Out:
# Addition:  tensor([7., 7., 9.])
# Subtraction:  tensor([ 3., -1., -7.])
# Multiplication:  tensor([10., 12.,  8.])
# Division:  tensor([2.5000, 0.7500, 0.1250])
# tensor([3., 1., 7.])

# %%
# math reduction
x = torch.randn([2, 5])
print(x)
print(x.sum())
print(x.abs().sum())
print(x.sum(dim=1))
print(x.max().item()) # for 0d tensors
print(x.min(dim=1))
# Out:
# tensor([[-1.3860,  0.1473, -1.4041,  0.8017,  0.4205],
#         [ 1.7959,  0.9548, -0.8533,  0.0125, -0.7602]])
# tensor(-0.2708)
# tensor(8.5365)
# tensor([-1.4206,  1.1498])
# 1.795941948890686
# torch.return_types.min(
# values=tensor([-1.4041, -0.8533]),
# indices=tensor([2, 2]))

# %%
# linear algebra operations
x = torch.tensor([ 10., 20., 30.])
m = torch.Tensor([[0,0,1],[0,2,0],[5,0,0]])
print(m.mv(x))
print(m @ x)
# Out:
# tensor([30., 40., 50.])
# tensor([30., 40., 50.])

# %%
print(m @ m.T)
# Out:
# tensor([[ 1.,  0.,  0.],
#         [ 0.,  4.,  0.],
#         [ 0.,  0., 25.]])

# %%
torch.inverse(m @ m.T)
# Out:
# tensor([[1.0000, 0.0000, 0.0000],
#         [0.0000, 0.2500, 0.0000],
#         [0.0000, 0.0000, 0.0400]])

# %%
# for more linalg operations see also torch.linalg
#help(torch.linalg)

# %% [markdown]
# #### torch <-> numpy

# %%
import numpy as np

# %%
xnp = np.array([[1,2],[3,4]])
x = torch.Tensor(xnp)
x
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
x[0,1]=5
xnp[1,0]=6
x, xnp
# Out:
# (tensor([[1., 5.],
#          [3., 4.]]),
#  array([[1, 2],
#         [6, 4]]))

# %%
xx = torch.from_numpy(xnp)
xx[0,1]=5
xnp[1,0]=7
xx, xnp
# Out:
# (tensor([[1, 5],
#          [7, 4]]),
#  array([[1, 5],
#         [7, 4]]))

# %%
xxnp=xx.numpy()
xx[0,1]=8
xxnp[1,0]=9
xx, xxnp
# Out:
# (tensor([[1, 8],
#          [9, 4]]),
#  array([[1, 8],
#         [9, 4]]))

# %% [markdown]
# #### Reshape

# %%
# Reshaping tensors
x = torch.rand([3, 4])
y = x.view([2, 6])
z = x.view(-1)
x, y, z
# Out:
# (tensor([[0.8400, 0.7301, 0.9739, 0.9105],
#          [0.5984, 0.2690, 0.3477, 0.0394],
#          [0.5539, 0.8474, 0.3453, 0.6317]]),
#  tensor([[0.8400, 0.7301, 0.9739, 0.9105, 0.5984, 0.2690],
#          [0.3477, 0.0394, 0.5539, 0.8474, 0.3453, 0.6317]]),
#  tensor([0.8400, 0.7301, 0.9739, 0.9105, 0.5984, 0.2690, 0.3477, 0.0394, 0.5539,
#          0.8474, 0.3453, 0.6317]))

# %%
z[0]=10
x, y, z
# Out:
# (tensor([[10.0000,  0.7301,  0.9739,  0.9105],
#          [ 0.5984,  0.2690,  0.3477,  0.0394],
#          [ 0.5539,  0.8474,  0.3453,  0.6317]]),
#  tensor([[10.0000,  0.7301,  0.9739,  0.9105,  0.5984,  0.2690],
#          [ 0.3477,  0.0394,  0.5539,  0.8474,  0.3453,  0.6317]]),
#  tensor([10.0000,  0.7301,  0.9739,  0.9105,  0.5984,  0.2690,  0.3477,  0.0394,
#           0.5539,  0.8474,  0.3453,  0.6317]))

# %%
xx = torch.rand([3, 4])
zz = xx.reshape(2,-1)
zz[0,1]=10
xx, zz
# Out:
# (tensor([[ 0.5393, 10.0000,  0.1532,  0.6341],
#          [ 0.8555,  0.1006,  0.9563,  0.0301],
#          [ 0.7814,  0.3876,  0.5619,  0.9694]]),
#  tensor([[ 0.5393, 10.0000,  0.1532,  0.6341,  0.8555,  0.1006],
#          [ 0.9563,  0.0301,  0.7814,  0.3876,  0.5619,  0.9694]]))
